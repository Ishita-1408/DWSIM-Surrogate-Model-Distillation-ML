# %% [markdown]
# ### Load Dataset

# %%
import pandas as pd

df = pd.read_csv("../Dataset/raw_simulation_data.csv")
df.head()
# Out:
#        T_feed    P_feed  z_benzene  reflux_ratio  stages  feed_stage  \
# 0  121.863389  1.165677   0.257171      4.146966    13.0         4.0
# 1   89.459707  1.638306   0.364948      4.224859    27.0         3.0
# 2  115.172163  1.843883   0.626730      4.901157    29.0        18.0
# 3  101.483985  1.810678   0.452148      3.934965    18.0         9.0
# 4  120.572133  1.436241   0.608326      3.059427    21.0        10.0
#
#    bottoms_flow        xD        xB          QC          QR
# 0     50.408283  0.732362  0.015341  363.691448 -373.005068
# 1     52.202497  0.763635  0.017705  508.301600 -306.094604
# 2     46.260664  0.987195  0.126703  636.041981 -250.296414
# 3     77.320856  0.782563  0.019401  626.130267 -251.510105
# 4     59.541746  0.978757  0.095971  634.435014 -250.295981

# %% [markdown]
# ### Dataset Shape

# %%
df.shape
# Out:
# (600, 11)

# %% [markdown]
# ### Check missing values

# %%
df.isnull().sum()
# Out:
# T_feed          0
# P_feed          0
# z_benzene       0
# reflux_ratio    0
# stages          0
# feed_stage      0
# bottoms_flow    0
# xD              0
# xB              0
# QC              0
# QR              0
# dtype: int64

# %% [markdown]
# ### Data Cleaning

# %%
df = df.dropna()

# %% [markdown]
# ### Save cleaned dataset

# %%
df.to_csv("../Dataset/cleaned_dataset.csv", index=False)
